# %%
# !pip install numpy pandas matplotlib seaborn
# Out:
# Requirement already satisfied: numpy in c:\users\dell\.conda\envs\akhil\lib\site-packages (2.2.6)
# Requirement already satisfied: pandas in c:\users\dell\.conda\envs\akhil\lib\site-packages (2.3.3)
# Requirement already satisfied: matplotlib in c:\users\dell\.conda\envs\akhil\lib\site-packages (3.10.9)
# Requirement already satisfied: seaborn in c:\users\dell\.conda\envs\akhil\lib\site-packages (0.13.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from matplotlib) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from matplotlib) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from matplotlib) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from matplotlib) (26.0)
# Requirement already satisfied: pillow>=8 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from matplotlib) (12.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from matplotlib) (3.3.2)
# Requirement already satisfied: six>=1.5 in c:\users\dell\.conda\envs\akhil\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
import numpy as np # linear algebra
import pandas as pd # data processing
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# f:\AI Engineer Roadmap\DAY 053 StandardScaler in scikit-learn
# ['3 Scikit-Learn StandarScaler Class.ipynb', 'Social_Network_Ads.csv']

# %%
df = pd.read_csv(r'F:\AI Engineer Roadmap\DAY 053 StandardScaler in scikit-learn\Social_Network_Ads.csv')

# %%
df['Gender'] = df['Gender'].map({'Male':1,'Female':0})

# %%
df.drop('User ID',axis=1,inplace=True)

# %%
df.shape
# Out:
# (400, 4)

# %% [markdown]
# # Train Test Split

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(df.drop('Purchased', axis=1),
                                                    df['Purchased'],
                                                    test_size=0.3,
                                                    random_state=0
                                                    )

X_train.shape, X_test.shape
# Out:
# ((280, 3), (120, 3))

# %% [markdown]
# # Applying StandarScaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# fit the scaler to the train set, it will learn the parameters
scaler.fit(X_train)

# transform train and test sets
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled = pd.DataFrame(data=X_train_scaled,columns=X_train.columns)
X_test_scaled = pd.DataFrame(data=X_test_scaled,columns=X_train.columns)

# %%
np.round(X_train.describe(),2)
# Out:
#        Gender     Age  EstimatedSalary
# count   280.0  280.00           280.00
# mean      0.5   37.86         69807.14
# std       0.5   10.22         34641.20
# min       0.0   18.00         15000.00
# 25%       0.0   30.00         43000.00
# 50%       1.0   37.00         70500.00
# 75%       1.0   46.00         88000.00
# max       1.0   60.00        150000.00

# %%
np.round(X_train_scaled.describe(),2)
# Out:
#        Gender     Age  EstimatedSalary
# count  280.00  280.00           280.00
# mean    -0.00    0.00             0.00
# std      1.00    1.00             1.00
# min     -1.01   -1.95            -1.58
# 25%     -1.01   -0.77            -0.78
# 50%      0.99   -0.08             0.02
# 75%      0.99    0.80             0.53
# max      0.99    2.17             2.32

# %%
fig,(x1,x2) = plt.subplots(1,2,figsize=(15,4))
x1.scatter(X_train['Age'],X_train['EstimatedSalary'])
plt.title("before")
plt.xlabel("Age")
plt.ylabel('Salary')
x2.scatter(X_train_scaled['Age'],X_train_scaled['EstimatedSalary'],color='red')
plt.title('after scaling')
plt.xlabel("Age")
plt.ylabel('Salary')
plt.show()
