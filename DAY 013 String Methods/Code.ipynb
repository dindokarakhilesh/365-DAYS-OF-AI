# %%
# Strings are immutable
a = "!!!Harry!! !!!!!!!!! Harry !!!!!!!!!!!"
print(a)
# Out:
# !!!Harry!! !!!!!!!!! Harry !!!!!!!!!!!

# %%
# Finding a length of Strings
print(len(a))
# Out:
# 38

# %%
# Converting a Strings into Upper-coas
print(a.upper())
# Out:
# !!!HARRY!! !!!!!!!!! HARRY !!!!!!!!!!!

# %%
# Converting a Strings into Lower-coas
print(a.lower())
# Out:
# !!!harry!! !!!!!!!!! harry !!!!!!!!!!!

# %%
# Remove into string
print(a.rstrip("!"))
# Out:
# !!!Harry!! !!!!!!!!! Harry

# %%
# Remove any thing into string
print(a.replace("Harry", "John"))
# Out:
# !!!John!! !!!!!!!!! John !!!!!!!!!!!

# %%
print(a.split(" "))
# Out:
# ['!!!Harry!!', '!!!!!!!!!', 'Harry', '!!!!!!!!!!!']

# %%
blogHeading = "introduction tO jS"
print(blogHeading.capitalize())
# Out:
# Introduction to js

# %%
str1 = "Welcome to the Console!!!"
print(len(str1))
print(len(str1.center(50)))
print(a.count("Harry"))
# Out:
# 25
# 50
# 2

# %%
str1 = "Welcome to the Console !!!"
print(str1.endswith("!!!"))
# Out:
# True

# %%
str1 = "Welcome to the Console !!!"
print(str1.endswith("to", 4, 10))
# Out:
# True

# %%
str1 = "He's name is Dan. He is an honest man."
print(str1.find("is"))
# Out:
# 10

# %%
str1 = "He's name is Dan. He is an honest man."
print(str1.find("ish"))
# Out:
# -1

# %%
str1 = "He's name is Dan. He is an honest man."
print(str1.index("is"))
# Out:
# 10

# %%
str1 = "He's name is Dan. He is an honest man."
print(str1.index("ishh"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[76], line 2
#       1 str1 = "He's name is Dan. He is an honest man."
# ----> 2 print(str1.index("ishh"))
#
# ValueError: substring not found

# %%
str1 = "WelcomeToTheConsole"
print(str1.isalnum())
str1 = "Welcome"
print(str1.isalpha())
# Out:
# True
# False

# %%
str1 = "Welcome To The Console"
print(str1.isalnum())
str1 = "Welcome\n"
print(str1.isalpha())
# Out:
# False
# False

# %%
str1 = "hello world"
print(str1.islower())
# Out:
# True

# %%
str1 = "Hello world"
print(str1.islower())
# Out:
# False

# %%
str1 = "We wish you a Merry Christmas\n"
print(str1.isprintable())
str1 = "         "       #using Spacebar
print(str1.isspace())
str2 = "  "       #using Tab
print(str2.isspace())
# Out:
# False
# True
# True

# %%
str1 = "World Health Organization" 
print(str1.istitle())
# Out:
# True

# %%
str2 = "To kill a Mocking bird"
print(str2.istitle())
# Out:
# False

# %%
str1 = "Python is a Interpreted Language" 
print(str1.startswith("Python"))
# Out:
# True

# %%
str1 = "Python is a Interpreted Language" 
print(str1.swapcase())
# Out:
# pYTHON IS A iNTERPRETED lANGUAGE

# %%
str1 = "His name is Dan. Dan is an honest man."
print(str1.title())
# Out:
# His Name Is Dan. Dan Is An Honest Man.
