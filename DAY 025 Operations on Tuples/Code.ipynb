# %%
countries = ("Spain", "Italy", "India", "England", "Germany")
temp = list(countries)
temp.append("Russia")       #add item 
temp.pop(3)                 #remove item
temp[2] = "Finland"         #change item
countries = tuple(temp)
print(countries)
# Out:
# ('Spain', 'Italy', 'Finland', 'Germany', 'Russia')

# %%
countries = ("Pakistan", "Afghanistan", "Bangladesh", "ShriLanka")
countries2 = ("Vietnam", "India", "China")
southEastAsia = countries + countries2
print(southEastAsia)
# Out:
# ('Pakistan', 'Afghanistan', 'Bangladesh', 'ShriLanka', 'Vietnam', 'India', 'China')

# %%
Tuple1 = (0, 1, 2, 3, 2, 3, 1, 3, 2)
res = Tuple1.count(3)
print('Count of 3 in Tuple1 is:', res)
# Out:
# Count of 3 in Tuple1 is: 3

# %%
Tuple = (0, 1, 2, 3, 2, 3, 1, 3, 2)
res = Tuple.index(3)
print('First occurrence of 3 is', res)
# Out:
# First occurrence of 3 is 3

# %%
tuple2 = (0, 1, 2, 3, 2, 31, 1, 3, 2, 3)
print(tuple2)
# Out:
# (0, 1, 2, 3, 2, 31, 1, 3, 2, 31)

# %%
res = tuple2.count(3)
print('Count of 3 in tuple1 is:', res)
# Out:
# Count of 3 in tuple1 is: 2

# %%
res = tuple2.index(3)
print('Count of 3 in tuple1 is:', res)
# Out:
# Count of 3 in tuple1 is: 3

# %%
res = tuple2.index(311)
print(res)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 res = tuple2.index(311)
#       2 print(res)
#
# ValueError: tuple.index(x): x not in tuple

# %%
res = tuple2.index(3, 4, 8)
print('Count of 3 in range of 4 to 8 in tuple1 is:', res)
# Out:
# Count of 3 in range of 4 to 8 in tuple1 is: 7

# %%
res = len(tuple2)
print('The length of tuple1 is:', res)
# Out:
# The length of tuple1 is: 10
