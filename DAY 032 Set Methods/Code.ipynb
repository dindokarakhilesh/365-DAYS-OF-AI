# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
cities3 = cities.union(cities2)
print(cities3)
# Out:
# {'Delhi', 'Tokyo', 'Kabul', 'Seoul', 'Madrid', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
cities.update(cities2)
print(cities)
# Out:
# {'Delhi', 'Tokyo', 'Kabul', 'Seoul', 'Madrid', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
cities3 = cities.intersection(cities2)
print(cities3)
# Out:
# {'Madrid', 'Tokyo'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
cities.intersection_update(cities2)
print(cities)
# Out:
# {'Madrid', 'Tokyo'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
cities3 = cities.symmetric_difference(cities2)
print(cities3)
# Out:
# {'Delhi', 'Kabul', 'Seoul', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
cities.symmetric_difference_update(cities2)
print(cities)
# Out:
# {'Delhi', 'Kabul', 'Seoul', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Seoul", "Kabul", "Delhi"}
cities3 = cities.difference(cities2)
print(cities3)
# Out:
# {'Madrid', 'Tokyo', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Seoul", "Kabul", "Delhi"}
print(cities.difference(cities2))
# Out:
# {'Madrid', 'Tokyo', 'Berlin'}

# %%
# Set Methods

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Tokyo", "Seoul", "Kabul", "Madrid"}
print(cities.isdisjoint(cities2))
# Out:
# False

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Seoul", "Kabul"}
print(cities.issuperset(cities2))
cities3 = {"Seoul", "Madrid","Kabul"}
print(cities.issuperset(cities3))
# Out:
# False
# False

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Delhi", "Madrid"}
print(cities2.issubset(cities))
# Out:
# True

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities.add("Helsinki")
print(cities)
# Out:
# {'Delhi', 'Tokyo', 'Madrid', 'Helsinki', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities2 = {"Helsinki", "Warsaw", "Seoul"}
cities.update(cities2)
print(cities)
# Out:
# {'Madrid', 'Delhi', 'Helsinki', 'Tokyo', 'Seoul', 'Warsaw', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities.remove("Tokyo")
print(cities)
# Out:
# {'Madrid', 'Delhi', 'Berlin'}

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities.remove("Seoul")
print(cities)

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
item = cities.pop()
print(cities)
print(item)
# Out:
# {'Delhi', 'Tokyo', 'Berlin'}
# Madrid

# %%
cities3 = {"Tokyo", "Madrid", "Berlin", "Delhi"}
del cities3
print(cities3)

# %%
cities = {"Tokyo", "Madrid", "Berlin", "Delhi"}
cities.clear()
print(cities)
# Out:
# set()

# %%
info = {"Carla", 19, False, 5.9}
if "Carla" in info:
    print("Carla is present.")
else:
    print("Carla is absent.")
# Out:
# Carla is present.
