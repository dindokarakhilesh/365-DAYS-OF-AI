# %%
letter = "Hey my name is {} and I am from {}"
country = "India"
name = "Akhil"
print(letter.format(name, country))
# Out:
# Hey my name is Akhil and I am from India

# %%
print(letter.format(country, name))
# Out:
# Hey my name is India and I am from Akhil

# %%
letter = "Hey my name is {1} and I am from {0}"
print(letter.format(country, name))
# Out:
# Hey my name is Akhil and I am from India

# %%
print(f"Hey my name is {name} and I am from {country}")
country = "India"
name = "Akhil"
# Out:
# Hey my name is Akhil and I am from India

# %%
print(f"We use f-strings like this: Hey my name is {{name}} and I am from {{country}}")
# Out:
# We use f-strings like this: Hey my name is {name} and I am from {country}

# %%
price = 49.09999
txt = f"For only {price:.2f} dollars!"
print(txt)
# Out:
# For only 49.10 dollars!

# %%
price = 49.09999
print(txt.format(price))
# Out:
# For only 49.10 dollars!

# %%
price = 49.09999
txt = f"For only {price:.3f} dollars!"
print(txt)
# Out:
# For only 49.100 dollars!

# %%
price = 49.09999
txt = f"For only {price:.2f} dollars!"
print(txt)
# Out:
# For only 49.10 dollars!

# %%
print(f"{2 * 30}")
# Out:
# 60

# %%
print(type(f"{2 * 30}"))
# Out:
# <class 'str'>
