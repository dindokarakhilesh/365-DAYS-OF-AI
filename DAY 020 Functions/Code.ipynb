# %%
def calculate(a, b):
    print(a, "+", b, "=",a+b)
    print(a, "-", b, "=",a-b)
    print(a, "*", b, "=",a*b)
    print(a, "/", b, "=",a/b)
    print("hre are the all arithmetic operation  of", a, "and", b)

# %%
a = 10
b = 20
calculate(a, b)
c = 23
d = 2.3
calculate(c, d)
# Out:
# 10 + 20 = 30
# 10 - 20 = -10
# 10 * 20 = 200
# 10 / 20 = 0.5
# hre are the all arithmetic operation  of 10 and 20
# 23 + 2.3 = 25.3
# 23 - 2.3 = 20.7
# 23 * 2.3 = 52.9
# 23 / 2.3 = 10.0
# hre are the all arithmetic operation  of 23 and 2.3

# %%
def isGreater(a, b):
    if a > b:
        print("First number is Greater")
    elif a == b:
        print("Both numbers are equal")
    else:
        print("Second number is Greater")

# %%
a = 1.123
b = 1.67
isGreater(a, b)
# Out:
# Second number is Greater

# %%
def isSmaller(a, b):
# Out:
#   Cell In[16], line 4
#
#     ^
# SyntaxError: incomplete input

# %%
def isSmaller(a, b):
    pass

# %%
a="hloo"
print(len(a))
# Out:
# 4

# %%
import math

print(math.sqrt(25))
# Out:
# 5.0

# %%
import math

print(math.floor(4.9))
# Out:
# 4

# %%
import math

print(math.floor(5.0))
# Out:
# 5

# %%
import math

print(math.pi)
# Out:
# 3.141592653589793
