# %%
name = "Akhil"
friend = "Davraj"
anotherFriend = 'Rohan'
apple = '''He said, 
Hi Harry
hey I am good
"I want to eat an apple'''

# %%
print("Hello, " + name)
# Out:
# Hello, Akhil

# %%
print(apple)
# Out:
# He said,
# Hi Harry
# hey I am good
# "I want to eat an apple

# %%
print(name[0])
print(name[1])
print(name[2])
print(name[3])
print(name[4])
# print(name[5]) # Throws an error
# Out:
# A
# k
# h
# i
# l

# %%
print("Lets use a for loop\n")
for character in apple:
    print(character)
# Out:
# Lets use a for loop
#
# H
# e
#
# s
# a
# i
# d
# ,
#
#
#
# H
# i
#
# H
# a
# r
# r
# y
#
#
# h
# e
# y
#
# I
#
# a
# m
#
# g
# o
# o
# d
#
#
# "
# I
#
# w
# a
# n
# t
#
# t
# o
#
# e
# a
# t
#
# a
# n
#
# a
# p
# p
# l
# e
