# %%
print(5+6)
# Out:
# 11

# %%
print(15-6)
# Out:
# 9

# %%
print(15*6)
# Out:
# 90

# %%
print(15*6)
# Out:
# 90

# %%
print(15/6)
# Out:
# 2.5

# %%
print(15//6)
# Out:
# 2

# %%
print(5%3)
# Out:
# 2

# %%
print(2**4)
# Out:
# 16
